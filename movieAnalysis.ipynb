# %%
import pandas as pd
movies_df=pd.read_csv('movies.csv')
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_df.title.value_counts()[:25].plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
ratings_df=pd.read_csv('ratings.csv')
tags_df=pd.read_csv('tags.csv')

# %%
ratings_df.head(30)
# Out:
#     userId  movieId  rating  timestamp
# 0        1        1     4.0  964982703
# 1        1        3     4.0  964981247
# 2        1        6     4.0  964982224
# 3        1       47     5.0  964983815
# 4        1       50     5.0  964982931
# 5        1       70     3.0  964982400
# 6        1      101     5.0  964980868
# 7        1      110     4.0  964982176
# 8        1      151     5.0  964984041
# 9        1      157     5.0  964984100
# 10       1      163     5.0  964983650
# 11       1      216     5.0  964981208
# 12       1      223     3.0  964980985
# 13       1      231     5.0  964981179
# 14       1      235     4.0  964980908
# 15       1      260     5.0  964981680
# 16       1      296     3.0  964982967
# 17       1      316     3.0  964982310
# 18       1      333     5.0  964981179
# 19       1      349     4.0  964982563
# 20       1      356     4.0  964980962
# 21       1      362     5.0  964982588
# 22       1      367     4.0  964981710
# ...

# %%
ratings_df.userId.value_counts()[:25].plot(kind='bar')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4204\1731113894.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   ratings_df.userId.value_counts()[:25].plot(kind='bar')
# <AxesSubplot: >

# %%
ratings_df.groupby('userId')['rating'].mean()[:25].plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='userId'>

# %%
#concat
#merge
new_df=pd.concat([movies_df,ratings_df])
new_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  userId  rating  timestamp
# 0  Adventure|Animation|Children|Comedy|Fantasy     NaN     NaN        NaN
# 1                   Adventure|Children|Fantasy     NaN     NaN        NaN
# 2                               Comedy|Romance     NaN     NaN        NaN
# 3                         Comedy|Drama|Romance     NaN     NaN        NaN
# 4                                       Comedy     NaN     NaN        NaN

# %%
new_df.tail()
# Out:
#         movieId title genres  userId  rating     timestamp
# 100831   166534   NaN    NaN   610.0     4.0  1.493848e+09
# 100832   168248   NaN    NaN   610.0     5.0  1.493850e+09
# 100833   168250   NaN    NaN   610.0     5.0  1.494273e+09
# 100834   168252   NaN    NaN   610.0     5.0  1.493846e+09
# 100835   170875   NaN    NaN   610.0     3.0  1.493846e+09

# %%
new=pd.merge(movies_df,ratings_df,on="movieId")
new.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movieId    100836 non-null  int64
#  1   title      100836 non-null  object
#  2   genres     100836 non-null  object
#  3   userId     100836 non-null  int64
#  4   rating     100836 non-null  float64
#  5   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.4+ MB

# %%
new_df3=pd.merge(movies_df,ratings_df,left_on="movieId",right_on="movieId")
new_df3
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
new_df3=pd.merge(movies_df,ratings_df,left_on="movieId",right_on="movieId",how="right")
new_df3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1                                    Comedy|Romance       1     4.0
# 2                             Action|Crime|Thriller       1     4.0
# 3                                  Mystery|Thriller       1     5.0
# ...

# %%
del new_df3['timestamp']

# %%
new_df3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1                                    Comedy|Romance       1     4.0
# 2                             Action|Crime|Thriller       1     4.0
# 3                                  Mystery|Thriller       1     5.0
# ...

# %%
new_df3.groupby('movieId')['rating'].mean()
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
new_df3.groupby('title')['rating'].mean()
# Out:
# title
# '71 (2014)                                   4.000000
# 'Hellboy': The Seeds of Creation (2004)      4.000000
# 'Round Midnight (1986)                       3.500000
# 'Salem's Lot (2004)                          5.000000
# 'Til There Was You (1997)                    4.000000
#                                                ...
# eXistenZ (1999)                              3.863636
# xXx (2002)                                   2.770833
# xXx: State of the Union (2005)               2.000000
# ¡Three Amigos! (1986)                        3.134615
# À nous la liberté (Freedom for Us) (1931)    1.000000
# Name: rating, Length: 9719, dtype: float64

# %%
new_df3.groupby('title')['userId'].count()
# Out:
# title
# '71 (2014)                                    1
# 'Hellboy': The Seeds of Creation (2004)       1
# 'Round Midnight (1986)                        2
# 'Salem's Lot (2004)                           1
# 'Til There Was You (1997)                     2
#                                              ..
# eXistenZ (1999)                              22
# xXx (2002)                                   24
# xXx: State of the Union (2005)                5
# ¡Three Amigos! (1986)                        26
# À nous la liberté (Freedom for Us) (1931)     1
# Name: userId, Length: 9719, dtype: int64

# %%
new_df3.groupby('title')['rating'].mean().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 new_df3.groupby('title')['rating'].mean().plot(kind='bar')
#
# NameError: name 'new_df3' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 new_df3=pd.merge(movies_df,ratings_df,left_on="movieId",right_on="movieId",how="right")
#       2 new_df3
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
movies_df=pd.read_csv('movies.csv')
ratings_df=pd.read_csv('ratings.csv')

# %%
new_df3=pd.merge(movies_df,ratings_df,left_on="movieId",right_on="movieId",how="right")
new_df3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1                                    Comedy|Romance       1     4.0
# 2                             Action|Crime|Thriller       1     4.0
# 3                                  Mystery|Thriller       1     5.0
# ...

# %%
del new_df3['timestamp']

# %%
new_df3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1                                    Comedy|Romance       1     4.0
# 2                             Action|Crime|Thriller       1     4.0
# 3                                  Mystery|Thriller       1     5.0
# ...

# %%
new_df3.groupby('title')['rating'].mean()[:25].plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='title'>

# %%
new_df3.groupby('title')['userId'].count()[:25].plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='title'>

# %%
new_df3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1                                    Comedy|Romance       1     4.0
# 2                             Action|Crime|Thriller       1     4.0
# 3                                  Mystery|Thriller       1     5.0
# ...

# %%
new_df4=new_df3.groupby('title')['rating'].mean()

# %%
type(new_df4)
# Out:
# pandas.core.series.Series

# %%
new_df4=new_df3.groupby('title')['rating'].mean().reset_index()
type(new_df4)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df4
# Out:
#                                           title    rating
# 0                                    '71 (2014)  4.000000
# 1       'Hellboy': The Seeds of Creation (2004)  4.000000
# 2                        'Round Midnight (1986)  3.500000
# 3                           'Salem's Lot (2004)  5.000000
# 4                     'Til There Was You (1997)  4.000000
# ...                                         ...       ...
# 9714                            eXistenZ (1999)  3.863636
# 9715                                 xXx (2002)  2.770833
# 9716             xXx: State of the Union (2005)  2.000000
# 9717                      ¡Three Amigos! (1986)  3.134615
# 9718  À nous la liberté (Freedom for Us) (1931)  1.000000
#
# [9719 rows x 2 columns]

# %%
new_df3.head()
del new_df3['rating']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
new_df4.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
new_df6=pd.merge(new_df3,new_df4,on="title")
new_df6
# Out:
#         movieId                             title  \
# 0             1                  Toy Story (1995)
# 1             1                  Toy Story (1995)
# 2             1                  Toy Story (1995)
# 3             1                  Toy Story (1995)
# 4             1                  Toy Story (1995)
# ...         ...                               ...
# 100831   160341                  Bloodmoon (1997)
# 100832   160527  Sympathy for the Underdog (1971)
# 100833   160836                     Hazard (2005)
# 100834   163937                Blair Witch (2016)
# 100835   163981                         31 (2016)
#
#                                              genres  userId   rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       1  3.92093
# 1       Adventure|Animation|Children|Comedy|Fantasy       5  3.92093
# 2       Adventure|Animation|Children|Comedy|Fantasy       7  3.92093
# 3       Adventure|Animation|Children|Comedy|Fantasy      15  3.92093
# ...

# %%
new_df3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId
# 0       Adventure|Animation|Children|Comedy|Fantasy       1
# 1                                    Comedy|Romance       1
# 2                             Action|Crime|Thriller       1
# 3                                  Mystery|Thriller       1
# 4                            Crime|Mystery|Thriller       1
# ...

# %%
tags_df=pd.read_csv('tags.csv')
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
final_df=pd.merge(new_df6,tags_df,on='movieId')
final_df
# Out:
#         movieId                                              title  \
# 0             1                                   Toy Story (1995)
# 1             1                                   Toy Story (1995)
# 2             1                                   Toy Story (1995)
# 3             1                                   Toy Story (1995)
# 4             1                                   Toy Story (1995)
# ...         ...                                                ...
# 233208   176419                                     Mother! (2017)
# 233209   176419                                     Mother! (2017)
# 233210     7023               Wedding Banquet, The (Xi yan) (1993)
# 233211     6107  Night of the Shooting Stars (Notte di San Lore...
# 233212     6516                                   Anastasia (1956)
#
#                                              genres  userId_x   rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1  3.92093
# ...

# %%
del final_df['userId_x']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'userId_x'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
del final_df['userId_y']

# %%
final_df
# Out:
#         movieId                                              title  \
# 0             1                                   Toy Story (1995)
# 1             1                                   Toy Story (1995)
# 2             1                                   Toy Story (1995)
# 3             1                                   Toy Story (1995)
# 4             1                                   Toy Story (1995)
# ...         ...                                                ...
# 233208   176419                                     Mother! (2017)
# 233209   176419                                     Mother! (2017)
# 233210     7023               Wedding Banquet, The (Xi yan) (1993)
# 233211     6107  Night of the Shooting Stars (Notte di San Lore...
# 233212     6516                                   Anastasia (1956)
#
#                                              genres   rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy  3.92093
# ...

# %%
final_df1=final_df.groupby(['title','genres','rating','tag']).size().reset_index().groupby('title')
final_df1

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 del final_df1[0]
#
# TypeError: 'DataFrameGroupBy' object doesn't support item deletion
