# %%
import pandas as pd
df=pd.read_csv('pokemon.csv') #dataframe
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df[70:77]
# Out:
#      #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 70  65               Alakazam   Psychic     NaN    500  55      50       45
# 71  65  AlakazamMega Alakazam   Psychic     NaN    590  55      50       65
# 72  66                 Machop  Fighting     NaN    305  70      80       50
# 73  67                Machoke  Fighting     NaN    405  80     100       70
# 74  68                Machamp  Fighting     NaN    505  90     130       80
# 75  69             Bellsprout     Grass  Poison    300  50      75       35
# 76  70             Weepinbell     Grass  Poison    390  65      90       50
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 70      135       95    120           1      False
# 71      175       95    150           1      False
# 72       35       35     35           1      False
# 73       50       60     45           1      False
# 74       65       85     55           1      False
# 75       70       30     40           1      False
# ...

# %%
df[7:3:-1]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 4  4                 Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7      130       85    100           1      False
# 6      109       85    100           1      False
# 5       80       65     80           1      False
# 4       60       50     65           1      False

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df['HP'].describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %%
df[['HP','Defense']].describe()
# Out:
#                HP     Defense
# count  800.000000  800.000000
# mean    69.258750   73.842500
# std     25.534669   31.183501
# min      1.000000    5.000000
# 25%     50.000000   50.000000
# 50%     65.000000   70.000000
# 75%     80.000000   90.000000
# max    255.000000  230.000000

# %%
df['HP']
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
df.HP
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
df['Legendary'].describe()
# Out:
# count       800
# unique        2
# top       False
# freq        735
# Name: Legendary, dtype: object

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
df.loc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
df.loc[[4,7,77,777]]
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire     NaN    309  39      52
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 77    71                 Victreebel  Grass  Poison    490  80     105
# 777  707                     Klefki  Steel   Fairy    470  57      80
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# 7        111      130       85    100           1      False
# 77        65      100       70     70           1      False
# 777       91       80       87     75           6      False

# %%
df.iloc[7,2]
# Out:
# 'Fire'

# %%
df.select_dtypes(['int64'])
# Out:
#        #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      1    318  45      49       49       65       65     45           1
# 1      2    405  60      62       63       80       80     60           1
# 2      3    525  80      82       83      100      100     80           1
# 3      3    625  80     100      123      122      120     80           1
# 4      4    309  39      52       43       60       50     65           1
# ..   ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795  719    600  50     100      150      100      150     50           6
# 796  719    700  50     160      110      160      110    110           6
# 797  720    600  80     110       60      150      130     70           6
# 798  720    680  80     160       60      170      130     80           6
# 799  721    600  80     110      120      130       90     70           6
#
# [800 rows x 9 columns]

# %%
df.select_dtypes(['object'])
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
df.select_dtypes(['bool'])
# Out:
#      Legendary
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 795       True
# 796       True
# 797       True
# 798       True
# 799       True
#
# [800 rows x 1 columns]

# %%
new_df=df.select_dtypes(['object']).copy()

# %%
new_df[10:50]
# Out:
#                        Name    Type 1  Type 2
# 10                Wartortle     Water     NaN
# 11                Blastoise     Water     NaN
# 12  BlastoiseMega Blastoise     Water     NaN
# 13                 Caterpie       Bug     NaN
# 14                  Metapod       Bug     NaN
# 15               Butterfree       Bug  Flying
# 16                   Weedle       Bug  Poison
# 17                   Kakuna       Bug  Poison
# 18                 Beedrill       Bug  Poison
# 19    BeedrillMega Beedrill       Bug  Poison
# 20                   Pidgey    Normal  Flying
# 21                Pidgeotto    Normal  Flying
# 22                  Pidgeot    Normal  Flying
# 23      PidgeotMega Pidgeot    Normal  Flying
# 24                  Rattata    Normal     NaN
# 25                 Raticate    Normal     NaN
# 26                  Spearow    Normal  Flying
# 27                   Fearow    Normal  Flying
# 28                    Ekans    Poison     NaN
# ...

# %%
new_df.to_csv('mynewfile.csv')

# %%
df.isnull()
# Out:
#          #   Name  Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 0    False  False   False   False  False  False   False    False    False
# 1    False  False   False   False  False  False   False    False    False
# 2    False  False   False   False  False  False   False    False    False
# 3    False  False   False   False  False  False   False    False    False
# 4    False  False   False    True  False  False   False    False    False
# ..     ...    ...     ...     ...    ...    ...     ...      ...      ...
# 795  False  False   False   False  False  False   False    False    False
# 796  False  False   False   False  False  False   False    False    False
# 797  False  False   False   False  False  False   False    False    False
# 798  False  False   False   False  False  False   False    False    False
# 799  False  False   False   False  False  False   False    False    False
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Name'].isnull().sum()
# Out:
# 0

# %%
df['Type 1'].isnull().sum()
# Out:
# 0

# %%
new_df.head()
# Out:
#                     Name Type 1  Type 2
# 0              Bulbasaur  Grass  Poison
# 1                Ivysaur  Grass  Poison
# 2               Venusaur  Grass  Poison
# 3  VenusaurMega Venusaur  Grass  Poison
# 4             Charmander   Fire     NaN

# %%
new_df1=df.copy()
new_df1.head()
new_df1['Type 2'].isnull().sum()
# Out:
# 386

# %%
new=new_df1.fillna('AA')
new.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire      AA    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 2'].values
# Out:
# array(['Poison', 'Poison', 'Poison', 'Poison', nan, nan, 'Flying',
#        'Dragon', 'Flying', nan, nan, nan, nan, nan, nan, 'Flying',
#        'Poison', 'Poison', 'Poison', 'Poison', 'Flying', 'Flying',
#        'Flying', 'Flying', nan, nan, 'Flying', 'Flying', nan, nan, nan,
#        nan, nan, nan, nan, nan, 'Ground', nan, nan, 'Ground', nan, nan,
#        nan, nan, 'Fairy', 'Fairy', 'Flying', 'Flying', 'Poison', 'Poison',
#        'Poison', 'Grass', 'Grass', 'Poison', 'Poison', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 'Fighting', nan, nan, nan,
#        nan, nan, nan, nan, 'Poison', 'Poison', 'Poison', 'Poison',
#        'Poison', 'Ground', 'Ground', 'Ground', nan, nan, 'Psychic',
#        'Psychic', 'Psychic', 'Steel', 'Steel', 'Flying', 'Flying',
#        'Flying', nan, 'Ice', nan, nan, nan, 'Ice', 'Poison', 'Poison',
#        'Poison', 'Poison', 'Ground', nan, nan, nan, nan, nan, nan,
# ...

# %%
df['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
df.Defense.value_counts()
# Out:
# 70     54
# 50     49
# 60     46
# 80     39
# 40     36
#        ..
# 168     1
# 10      1
# 51      1
# 61      1
# 121     1
# Name: Defense, Length: 103, dtype: int64

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df[['Type 1','Type 2']].value_counts()
# Out:
# Type 1    Type 2
# Normal    Flying    24
# Grass     Poison    15
# Bug       Flying    14
#           Poison    12
# Ghost     Grass     10
#                     ..
# Fire      Rock       1
# Ice       Ghost      1
# Fire      Dragon     1
# Fighting  Flying     1
# Water     Steel      1
# Length: 136, dtype: int64

# %%
df[df.Attack]>100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df[df.Attack]>100
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv('pokemon.csv') #dataframe
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#Filtering
df.Attack>100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Attack, Length: 800, dtype: bool

# %%
df[df.Attack>100]
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# 12     9    BlastoiseMega Blastoise    Water     NaN    630   79     103
# 19    15      BeedrillMega Beedrill      Bug  Poison    495   65     150
# 39    34                   Nidoking   Poison  Ground    505   81     102
# ..   ...                        ...      ...     ...    ...  ...     ...
# 793  717                    Yveltal     Dark  Flying    680  126     131
# 796  719        DiancieMega Diancie     Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df.Attack>100) & (df.HP>70)]
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# 12     9    BlastoiseMega Blastoise    Water     NaN    630   79     103
# 39    34                   Nidoking   Poison  Ground    505   81     102
# 64    59                   Arcanine     Fire     NaN    555   90     110
# ..   ...                        ...      ...     ...    ...  ...     ...
# 792  716                    Xerneas    Fairy     NaN    680  126     131
# 793  717                    Yveltal     Dark  Flying    680  126     131
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df.Attack<100) | (df.HP>70)]
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318   45      49       49
# 1      2                Ivysaur    Grass  Poison    405   60      62       63
# 2      3               Venusaur    Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80     100      123
# 4      4             Charmander     Fire     NaN    309   39      52       43
# ..   ...                    ...      ...     ...    ...  ...     ...      ...
# 793  717                Yveltal     Dark  Flying    680  126     131       95
# 794  718       Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721              Volcanion     Fire   Water    600   80     110      120
#
# ...

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df[df['Type 1']=='Ice']
# Out:
#        #               Name Type 1   Type 2  Total   HP  Attack  Defense  \
# 133  124               Jynx    Ice  Psychic    455   65      50       35
# 156  144           Articuno    Ice   Flying    580   90      85      100
# 238  220             Swinub    Ice   Ground    250   50      50       40
# 239  221          Piloswine    Ice   Ground    450  100     100       80
# 243  225           Delibird    Ice   Flying    330   45      55       45
# 257  238           Smoochum    Ice  Psychic    305   45      30       15
# 395  361            Snorunt    Ice      NaN    300   50      50       50
# 396  362             Glalie    Ice      NaN    480   80      80       80
# 397  362  GlalieMega Glalie    Ice      NaN    580   80     120       80
# 398  363             Spheal    Ice    Water    290   70      40       50
# 399  364             Sealeo    Ice    Water    410   90      60       70
# 400  365            Walrein    Ice    Water    530  110      80       90
# ...

# %%
df['Type 2'].str.contains('Flying')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4        NaN
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 2, Length: 800, dtype: object

# %%
df[df['Type 1'].str.contains('Ic')]
# Out:
#        #               Name Type 1   Type 2  Total   HP  Attack  Defense  \
# 133  124               Jynx    Ice  Psychic    455   65      50       35
# 156  144           Articuno    Ice   Flying    580   90      85      100
# 238  220             Swinub    Ice   Ground    250   50      50       40
# 239  221          Piloswine    Ice   Ground    450  100     100       80
# 243  225           Delibird    Ice   Flying    330   45      55       45
# 257  238           Smoochum    Ice  Psychic    305   45      30       15
# 395  361            Snorunt    Ice      NaN    300   50      50       50
# 396  362             Glalie    Ice      NaN    480   80      80       80
# 397  362  GlalieMega Glalie    Ice      NaN    580   80     120       80
# 398  363             Spheal    Ice    Water    290   70      40       50
# 399  364             Sealeo    Ice    Water    410   90      60       70
# 400  365            Walrein    Ice    Water    530  110      80       90
# ...

# %%
df['HP']+df['Attack']
# Out:
# 0       94
# 1      122
# 2      162
# 3      180
# 4       91
#       ...
# 795    150
# 796    210
# 797    190
# 798    240
# 799    190
# Length: 800, dtype: int64

# %%
(df.HP+df.Attack+df.Speed)/3
# Out:
# 0       46.333333
# 1       60.666667
# 2       80.666667
# 3       86.666667
# 4       52.000000
#           ...
# 795     66.666667
# 796    106.666667
# 797     86.666667
# 798    106.666667
# 799     86.666667
# Length: 800, dtype: float64

# %%
df['newcol']=df.HP+df.Attack

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcol
# 0       65       65     45           1      False      94
# 1       80       80     60           1      False     122
# 2      100      100     80           1      False     162
# 3      122      120     80           1      False     180
# 4       60       50     65           1      False      91

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'newcol'],
#       dtype='object')

# %%
del df['newcol']

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
row=df.loc[0]

# %%
row
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
new_df=df.append(row,ignore_index=True)
new_df.tail()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_12732\724389023.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df=df.append(row,ignore_index=True)
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 796  719  DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
# 800    1            Bulbasaur    Grass  Poison    318  45      49       49
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df[df['Type 1']=="Ice"][['Name','HP']]
# Out:
#                   Name   HP
# 133               Jynx   65
# 156           Articuno   90
# 238             Swinub   50
# 239          Piloswine  100
# 243           Delibird   45
# 257           Smoochum   45
# 395            Snorunt   50
# 396             Glalie   80
# 397  GlalieMega Glalie   80
# 398             Spheal   70
# 399             Sealeo   90
# 400            Walrein  110
# 415             Regice   80
# 522            Glaceon   65
# 524          Mamoswine  110
# 530           Froslass   70
# 643          Vanillite   36
# 644          Vanillish   51
# 645          Vanilluxe   71
# 674            Cubchoo   55
# 675            Beartic   95
# 676          Cryogonal   70
# 788           Bergmite   55
# 789            Avalugg   95

# %%
df[(df['HP']>70) & (df['Type 1']=="Ice")].Name
# Out:
# 156             Articuno
# 239            Piloswine
# 396               Glalie
# 397    GlalieMega Glalie
# 399               Sealeo
# 400              Walrein
# 415               Regice
# 524            Mamoswine
# 645            Vanilluxe
# 675              Beartic
# 789              Avalugg
# Name: Name, dtype: object

# %%
sum(df[df['Type 1']=='Ice'].HP)
# Out:
# 1728

# %%
max(df['HP'])
# Out:
# 255

# %%
#Update
new_df.loc[3]
# Out:
# #                                 3
# Name          VenusaurMega Venusaur
# Type 1                        Grass
# Type 2                       Poison
# Total                           625
# HP                               80
# Attack                          100
# Defense                         123
# Sp. Atk                         122
# Sp. Def                         120
# Speed                            80
# Generation                        1
# Legendary                     False
# Name: 3, dtype: object

# %%
new_df.iloc[3,2]
# Out:
# 'Grass'

# %%
new_df.iloc[3,2]="Fire"
print("updated")
# Out:
# updated

# %%
new_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur   Fire  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
new_df.loc[3]
# Out:
# #                                 3
# Name          VenusaurMega Venusaur
# Type 1                         Fire
# Type 2                       Poison
# Total                           625
# HP                               80
# Attack                          100
# Defense                         123
# Sp. Atk                         122
# Sp. Def                         120
# Speed                            80
# Generation                        1
# Legendary                     False
# Name: 3, dtype: object

# %%
max(new_df.Attack)
# Out:
# 190

# %%
new_df[new_df.Attack==190]
# Out:
#        #                 Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True

# %%
#condition
bool_cond=new_df.Attack==190

#change value
new_df.loc[bool_cond,['Type 1']]=='Grass'

#query the changed value
new_df[new_df.Attack==190]
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45     190       49
# 1      2                Ivysaur    Grass  Poison    405  60     190       63
# 2      3               Venusaur    Grass  Poison    525  80     190       83
# 3      3  VenusaurMega Venusaur     Fire  Poison    625  80     190      123
# 4      4             Charmander     Fire     NaN    309  39     190       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     190      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     190       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     190       60
# 799  721              Volcanion     Fire   Water    600  80     190      120
# 800    1              Bulbasaur    Grass  Poison    318  45     190       49
#
# ...

# %%
cond1=new_df.Attack==190

#change value
new_df.loc[cond1,['Type 2','HP']]=["Poison",-1]

new_df[new_df.Attack==190]
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  -1     190       49
# 1      2                Ivysaur    Grass  Poison    405  -1     190       63
# 2      3               Venusaur    Grass  Poison    525  -1     190       83
# 3      3  VenusaurMega Venusaur     Fire  Poison    625  -1     190      123
# 4      4             Charmander     Fire  Poison    309  -1     190       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 796  719    DiancieMega Diancie     Rock  Poison    700  -1     190      110
# 797  720    HoopaHoopa Confined  Psychic  Poison    600  -1     190       60
# 798  720     HoopaHoopa Unbound  Psychic  Poison    680  -1     190       60
# 799  721              Volcanion     Fire  Poison    600  -1     190      120
# 800    1              Bulbasaur    Grass  Poison    318  -1     190       49
#
# ...

# %%
#Update data (two cols) with two different condition
cond2=(new_df.Attack==190) & (new_df.Speed==130)

new_df.loc[cond2,['Name','Generation']]=["Aung Aung",0]

new_df[new_df.Attack==190]
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  -1     190       49
# 1      2                Ivysaur    Grass  Poison    405  -1     190       63
# 2      3               Venusaur    Grass  Poison    525  -1     190       83
# 3      3  VenusaurMega Venusaur     Fire  Poison    625  -1     190      123
# 4      4             Charmander     Fire  Poison    309  -1     190       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 796  719    DiancieMega Diancie     Rock  Poison    700  -1     190      110
# 797  720    HoopaHoopa Confined  Psychic  Poison    600  -1     190       60
# 798  720     HoopaHoopa Unbound  Psychic  Poison    680  -1     190       60
# 799  721              Volcanion     Fire  Poison    600  -1     190      120
# 800    1              Bulbasaur    Grass  Poison    318  -1     190       49
#
# ...

# %%
import pandas as pd
df=pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 2'].value_counts().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df['Type 2'].value_counts().plot()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 2'].value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
df['Type 2'].value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
df['Type 1'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
import pandas as pd
df=pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 2'].value_counts().plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df['Type 2'].value_counts().plot()
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     919 def __call__(self, *args, **kwargs):
# --> 920     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     922     x, y, kind, kwargs = self._get_call_args(
#     923         plot_backend.__name__, self._parent, args, kwargs
#     924     )
#     926     kind = self._kind_aliases.get(kind, kind)
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\plotting\_core.py:1898, in _get_plot_backend(backend)
#    1895 if backend_str in _backends:
#    1896     return _backends[backend_str]
# -> 1898 module = _load_backend(backend_str)
#    1899 _backends[backend_str] = module
# ...

# %%
df['Type 2'].value_counts().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df['Type 2'].value_counts().plot()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 2'].value_counts().plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 df['Type 2'].value_counts().plot()
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     919 def __call__(self, *args, **kwargs):
# --> 920     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     922     x, y, kind, kwargs = self._get_call_args(
#     923         plot_backend.__name__, self._parent, args, kwargs
#     924     )
#     926     kind = self._kind_aliases.get(kind, kind)
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\plotting\_core.py:1898, in _get_plot_backend(backend)
#    1895 if backend_str in _backends:
#    1896     return _backends[backend_str]
# -> 1898 module = _load_backend(backend_str)
#    1899 _backends[backend_str] = module
# ...

# %%
import matplotlib.pyplot as plt

df['Type 2'].value_counts.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 import matplotlib.pyplot as plt
#       3 df['Type 2'].value_counts.plot()
#
# ModuleNotFoundError: No module named 'matplotlib'
