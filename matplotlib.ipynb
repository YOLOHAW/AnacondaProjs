# %%
import pandas as pd
import matplotlib
df=pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 2'].value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
df['Type 1'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df[['Type 1','HP']].plot()
# Out:
# <AxesSubplot: >

# %%
import matplotlib

# %%
# !pip install matplotlib

# %%
import matplotlib
import pandas as pd
df=pd.read_csv('pokemon.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 import matplotlib
#       2 import pandas as pd
#       3 df=pd.read_csv('pokemon.csv')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip3 install matplotlib

# %%
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 1.1 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# C:\Users\lenovo\anaconda3\envs\mibaDesktop\python.exe -m pip install --upgrade pip

# %%
# Out:
# ...
#   Using cached pip-22.3.1-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# ...

# %%
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !python3 -m pip install -U matplotlib
# Out:
# 'python3' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !conda install matplotlib
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import matplotlib

# %%
df[['Type 1','HP']].plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df.head(30)
# Out:
#      #                       Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur   Grass  Poison    318  45      49       49
# 1    2                    Ivysaur   Grass  Poison    405  60      62       63
# 2    3                   Venusaur   Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4    4                 Charmander    Fire     NaN    309  39      52       43
# 5    5                 Charmeleon    Fire     NaN    405  58      64       58
# 6    6                  Charizard    Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X    Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y    Fire  Flying    634  78     104       78
# 9    7                   Squirtle   Water     NaN    314  44      48       65
# 10   8                  Wartortle   Water     NaN    405  59      63       80
# ...

# %%
new_df=df.groupby('Type 1',as_index=False)['HP'].mean()
new_df
# Out:
#       Type 1         HP
# 0        Bug  56.884058
# 1       Dark  66.806452
# 2     Dragon  83.312500
# 3   Electric  59.795455
# 4      Fairy  74.117647
# 5   Fighting  69.851852
# 6       Fire  69.903846
# 7     Flying  70.750000
# 8      Ghost  64.437500
# 9      Grass  67.271429
# 10    Ground  73.781250
# 11       Ice  72.000000
# 12    Normal  77.275510
# 13    Poison  67.250000
# 14   Psychic  70.631579
# 15      Rock  65.363636
# 16     Steel  65.222222
# 17     Water  72.062500

# %%
new_df.plot()
# Out:
# <AxesSubplot: >

# %%
new_df.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
#matplotlib
#seaborn
#streamlit

#manually
xvalue=['YGN','MDY',"BGO","MGN"]
yvalue=[100,200,300,400]

df=pd.DataFrame({"city":xvalue,"value":yvalue})
df.plot(x="city",y="value")
# Out:
# <AxesSubplot: xlabel='city'>

# %%
activate mibaDesktop
conda install matplotlib
conda install seaborn
# Out:
#   Input In [26]
#     activate mibaDesktop
#              ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pylot as pt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 import matplotlib.pylot as pt
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
import matplotlib.pyplot as pt
from matplotlib.pyplot import figure
import pandas as pd

figure(figsize=(8,6),dpi=800)
pt.plot(df['Type 1'],df['HP'])
pt.xticks(rotation=90)
pt.xlabel('Type 1')
pt.ylabel('HP')
pt.title("Date Compare")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\mibaDiploma\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type 1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import matplotlib-inline.pylot as pt
# Out:
#   Input In [3]
#     import matplotlib-inline.pylot as pt
#                      ^
# SyntaxError: invalid syntax

# %%
pip list
# Out:
# Package              Version
# -------------------- ---------
# altair               4.1.0
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                21.4.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               4.1.0
# blinker              1.4
# Bottleneck           1.3.5
# brotlipy             0.7.0
# cachetools           4.2.2
# certifi              2022.12.7
# cffi                 1.15.1
# charset-normalizer   2.0.4
# click                8.0.4
# colorama             0.4.5
# commonmark           0.9.1
# cryptography         38.0.4
# debugpy              1.5.1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# executing            0.8.3
# fastjsonschema       2.16.2
# future               0.18.2
# gitdb                4.0.7
# GitPython            3.1.18
# idna                 3.4
# importlib-metadata   4.11.3
# ipykernel            6.15.2
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 975.4 kB/s eta 0:00:00
# ...
#      ------------------------------------ 163.0/163.0 kB 972.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB 1.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 965.4/965.4 kB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\lenovo\anaconda3\envs\mibaDiploma\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip list
# Out:
# Package              Version
# -------------------- ---------
# altair               4.1.0
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                21.4.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               4.1.0
# blinker              1.4
# Bottleneck           1.3.5
# brotlipy             0.7.0
# cachetools           4.2.2
# certifi              2022.12.7
# cffi                 1.15.1
# charset-normalizer   2.0.4
# click                8.0.4
# colorama             0.4.5
# commonmark           0.9.1
# contourpy            1.0.7
# cryptography         38.0.4
# cycler               0.11.0
# debugpy              1.5.1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# executing            0.8.3
# fastjsonschema       2.16.2
# fonttools            4.38.0
# future               0.18.2
# gitdb                4.0.7
# GitPython            3.1.18
# ...

# %%
import matplotlib as pt
